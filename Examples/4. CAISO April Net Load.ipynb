# %% [markdown]
# ## CAISO April Net Load Trends
#
# We will be using the gridstatusio API client for data fetching, and Plotly for data visualization. You can register for a Grid Status api key here: https://www.gridstatus.io/api
#
# ### Installation
#
# To run this notebook, install the gridstatusio package with notebook dependencies:
#
# ```bash
# uv pip install gridstatusio[notebooks]
# ```

# %%
import pandas as pd
import plotly.graph_objects as go

import gridstatusio

gridstatusio.__version__
# Out:
# '0.13.0'

# %% [markdown]
# ## Initialize the gridstatusio client
#
# We instantiate the GridStatusClient, which we will use to fetch our data.

# %%
# Make sure to set up an API Key as an environment variable
# or pass it in as a string
client = gridstatusio.GridStatusClient()

# %% [markdown]
# ## Get data
#
# Fetch data using the GridStatusClient. We will get the `caiso_standardized_5_min` dataset from the beginning of the data to the most recent data.
#
# We are setting a `limit` value for our queries to prevent them from returning too many rows. Our `limit` is relatively high in this notebook and if you are on a Grid Status free plan, you will want to set a much lower `limit` to avoid quickly using your monthly row limit.
#
# The monthly row limit for the free plan is 1 million rows. The first tier Pro plan is 50 million rows.

# %%
QUERY_LIMIT = 750_000

# %%
import warnings

warnings.filterwarnings("ignore")

df = client.get_dataset(
    dataset="caiso_standardized_5_min",
    start=None,  # start from beginning of data
    end=None,  # end at most recent data
    timezone="market",  # return time stamps in market time. In this case, Pacific Time
)
# Out:
# 2025-07-28 08:20:46 - INFO - Fetching Page 1...
# 2025-07-28 08:20:46 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:20:46 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:20:49 - INFO - Done in 3.13 seconds.
# 2025-07-28 08:20:49 - INFO - Fetching Page 2...
# 2025-07-28 08:20:49 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:20:49 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 2, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAxOC0wOS0zMCAyMTo0MDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiA1MDAwMH0=', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:20:53 - INFO - Done in 3.96 seconds. Total time: 7.09s. Avg per page: 3.54s
# 2025-07-28 08:20:53 - INFO - Fetching Page 3...
# 2025-07-28 08:20:53 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:20:53 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 3, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAxOS0wMy0yMyAxMjoyMDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiAxMDAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:20:56 - INFO - Done in 3.03 seconds. Total time: 10.12s. Avg per page: 3.37s
# 2025-07-28 08:20:56 - INFO - Fetching Page 4...
# 2025-07-28 08:20:56 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:20:56 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 4, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAxOS0wOS0xMyAwMzowMDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiAxNTAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:21:00 - INFO - Done in 3.25 seconds. Total time: 13.37s. Avg per page: 3.34s
# 2025-07-28 08:21:00 - INFO - Fetching Page 5...
# 2025-07-28 08:21:00 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:21:00 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 5, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMC0wMy0wNCAxNzo0MDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiAyMDAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:21:04 - INFO - Done in 3.9 seconds. Total time: 17.27s. Avg per page: 3.45s
# 2025-07-28 08:21:04 - INFO - Fetching Page 6...
# 2025-07-28 08:21:04 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:21:04 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 6, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMC0wOC0yNSAwODoyMDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiAyNTAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:21:07 - INFO - Done in 3.27 seconds. Total time: 20.54s. Avg per page: 3.42s
# 2025-07-28 08:21:07 - INFO - Fetching Page 7...
# 2025-07-28 08:21:07 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:21:07 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 7, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMS0wMi0xNCAyMzowMDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiAzMDAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:21:11 - INFO - Done in 3.84 seconds. Total time: 24.38s. Avg per page: 3.48s
# 2025-07-28 08:21:11 - INFO - Fetching Page 8...
# 2025-07-28 08:21:11 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:21:11 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 8, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMS0wOC0wNyAxMzo0MDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiAzNTAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:21:14 - INFO - Done in 3.72 seconds. Total time: 28.1s. Avg per page: 3.51s
# 2025-07-28 08:21:14 - INFO - Fetching Page 9...
# 2025-07-28 08:21:14 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:21:14 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 9, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMi0wMS0yOCAwNDoyMDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiA0MDAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:21:18 - INFO - Done in 3.08 seconds. Total time: 31.18s. Avg per page: 3.46s
# 2025-07-28 08:21:18 - INFO - Fetching Page 10...
# 2025-07-28 08:21:18 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:21:18 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 10, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMi0wNy0yMCAxOTowMDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiA0NTAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:21:21 - INFO - Done in 3.55 seconds. Total time: 34.73s. Avg per page: 3.47s
# 2025-07-28 08:21:21 - INFO - Fetching Page 11...
# 2025-07-28 08:21:21 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:21:21 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 11, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMy0wMS0xMCAwOTo0MDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiA1MDAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:21:25 - INFO - Done in 3.8 seconds. Total time: 38.53s. Avg per page: 3.5s
# 2025-07-28 08:21:25 - INFO - Fetching Page 12...
# 2025-07-28 08:21:25 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:21:25 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 12, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMy0wNy0wMyAwMDoyMDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiA1NTAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:21:28 - INFO - Done in 3.23 seconds. Total time: 41.76s. Avg per page: 3.48s
# 2025-07-28 08:21:28 - INFO - Fetching Page 13...
# 2025-07-28 08:21:28 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:21:28 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 13, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMy0xMi0yMyAxNTowMDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiA2MDAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:21:32 - INFO - Done in 4.04 seconds. Total time: 45.79s. Avg per page: 3.52s
# 2025-07-28 08:21:32 - INFO - Fetching Page 14...
# 2025-07-28 08:21:32 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:21:32 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 14, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyNC0wNi0xNCAwNTo0MDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiA2NTAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:21:36 - INFO - Done in 3.51 seconds. Total time: 49.3s. Avg per page: 3.52s
# 2025-07-28 08:21:36 - INFO - Fetching Page 15...
# 2025-07-28 08:21:36 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:21:36 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 15, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyNC0xMi0wNCAyMDoyMDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiA3MDAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:21:39 - INFO - Done in 3.73 seconds. Total time: 53.03s. Avg per page: 3.54s
# 2025-07-28 08:21:39 - INFO - Fetching Page 16...
# 2025-07-28 08:21:39 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2025-07-28 08:21:39 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 16, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyNS0wNS0yNyAxMTowMDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiA3NTAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-07-28 08:21:41 - INFO - Done in 1.29 seconds. Total time: 54.32s. Avg per page: 3.39s
# 2025-07-28 08:21:42 - INFO - Total number of rows: 768101

# %%
import warnings

warnings.filterwarnings("ignore")

df = client.get_dataset(
    dataset="caiso_standardized_5_min",
    start=None,  # start from beginning of data
    end=None,  # end at most recent data
    timezone="market",  # return time stamps in market time. In this case, Pacific Time
    limit=QUERY_LIMIT,
)

df.head()

df.tail()

df.info()
# Out:
# Fetching Page 1...Done in 7.23 seconds.
# Total rows: 100,000/750,000 (13.33% of limit)
# Done in 7.44 seconds. Total time: 14.67s. Avg per page: 7.33s
# Total rows: 200,000/750,000 (26.67% of limit)
# Done in 6.4 seconds. Total time: 21.07s. Avg per page: 7.02s
# Total rows: 300,000/750,000 (40.0% of limit)
# Done in 8.16 seconds. Total time: 29.22s. Avg per page: 7.31s
# Total rows: 400,000/750,000 (53.33% of limit)
# Done in 7.07 seconds. Total time: 36.29s. Avg per page: 7.26s
# Total rows: 500,000/750,000 (66.67% of limit)
# Done in 7.0 seconds. Total time: 43.28s. Avg per page: 7.21s
# Total rows: 600,000/750,000 (80.0% of limit)
# Done in 7.04 seconds. Total time: 50.33s. Avg per page: 7.19s
# Total rows: 700,000/750,000 (93.33% of limit)
# Done in 1.63 seconds. Total time: 51.96s. Avg per page: 6.49s
# Total rows: 714,425/750,000 (95.26% of limit)
#
# Total number of rows: 714425
#             interval_start_local        interval_start_utc  \
# 0      2018-04-10 00:05:00-07:00 2018-04-10 07:05:00+00:00
# 1      2018-04-10 00:10:00-07:00 2018-04-10 07:10:00+00:00
# 2      2018-04-10 00:15:00-07:00 2018-04-10 07:15:00+00:00
# 3      2018-04-10 00:20:00-07:00 2018-04-10 07:20:00+00:00
# 4      2018-04-10 00:25:00-07:00 2018-04-10 07:25:00+00:00
# ...                          ...                       ...
# 714420 2025-01-23 14:05:00-08:00 2025-01-23 22:05:00+00:00
# 714421 2025-01-23 14:10:00-08:00 2025-01-23 22:10:00+00:00
# 714422 2025-01-23 14:15:00-08:00 2025-01-23 22:15:00+00:00
# 714423 2025-01-23 14:20:00-08:00 2025-01-23 22:20:00+00:00
# 714424 2025-01-23 14:25:00-08:00 2025-01-23 22:25:00+00:00
#
#               interval_end_local          interval_end_utc    net_load  \
# 0      2018-04-10 00:10:00-07:00 2018-04-10 07:10:00+00:00 21_953.0000
# 1      2018-04-10 00:15:00-07:00 2018-04-10 07:15:00+00:00 21_865.0000
# 2      2018-04-10 00:20:00-07:00 2018-04-10 07:20:00+00:00 21_687.0000
# 3      2018-04-10 00:25:00-07:00 2018-04-10 07:25:00+00:00 21_579.0000
# 4      2018-04-10 00:30:00-07:00 2018-04-10 07:30:00+00:00 21_432.0000
# ...                          ...                       ...         ...
# 714420 2025-01-23 14:10:00-08:00 2025-01-23 22:10:00+00:00         NaN
# 714421 2025-01-23 14:15:00-08:00 2025-01-23 22:15:00+00:00         NaN
# 714422 2025-01-23 14:20:00-08:00 2025-01-23 22:20:00+00:00         NaN
# 714423 2025-01-23 14:25:00-08:00 2025-01-23 22:25:00+00:00         NaN
# 714424 2025-01-23 14:30:00-08:00 2025-01-23 22:30:00+00:00         NaN
#
#         renewables  renewables_to_load_ratio primary_power_source   load.load  \
# 0       5_430.0000                    0.2427          natural_gas 22_371.0000
# 1       5_512.0000                    0.2468          natural_gas 22_330.0000
# 2       5_449.0000                    0.2468          natural_gas 22_082.0000
# 3       5_434.0000                    0.2472          natural_gas 21_978.0000
# 4       5_413.0000                    0.2478          natural_gas 21_844.0000
# ...            ...                       ...                  ...         ...
# 714420         NaN                       NaN                 None         NaN
# 714421         NaN                       NaN                 None         NaN
# 714422         NaN                       NaN                 None         NaN
# 714423         NaN                       NaN                 None         NaN
# 714424         NaN                       NaN                 None         NaN
#
#        load_forecast.publish_time_local load_forecast.publish_time_utc  \
# 0             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 1             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 2             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 3             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 4             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# ...                                 ...                            ...
# 714420        2025-01-22 09:10:00-08:00      2025-01-22 17:10:00+00:00
# 714421        2025-01-22 09:10:00-08:00      2025-01-22 17:10:00+00:00
# 714422        2025-01-22 09:10:00-08:00      2025-01-22 17:10:00+00:00
# 714423        2025-01-22 09:10:00-08:00      2025-01-22 17:10:00+00:00
# 714424        2025-01-22 09:10:00-08:00      2025-01-22 17:10:00+00:00
#
#         load_forecast.load_forecast  fuel_mix.solar  fuel_mix.wind  \
# 0                       22_362.7808          0.0000       418.0000
# 1                       22_260.1467          0.0000       465.0000
# 2                       22_157.5125          0.0000       395.0000
# 3                       22_054.8783          0.0000       399.0000
# 4                       21_952.2442          0.0000       412.0000
# ...                             ...             ...            ...
# 714420                  19_022.1800             NaN            NaN
# 714421                  19_022.1800             NaN            NaN
# 714422                  19_022.1800             NaN            NaN
# 714423                  19_022.1800             NaN            NaN
# 714424                  19_022.1800             NaN            NaN
#
#         fuel_mix.geothermal  fuel_mix.biomass  fuel_mix.biogas  \
# 0                  689.0000          296.0000         232.0000
# 1                  688.0000          297.0000         232.0000
# 2                  687.0000          296.0000         232.0000
# 3                  686.0000          295.0000         233.0000
# 4                  687.0000          293.0000         232.0000
# ...                     ...               ...              ...
# 714420                  NaN               NaN              NaN
# 714421                  NaN               NaN              NaN
# 714422                  NaN               NaN              NaN
# 714423                  NaN               NaN              NaN
# 714424                  NaN               NaN              NaN
#
#         fuel_mix.small_hydro  fuel_mix.coal  fuel_mix.nuclear  \
# 0                   370.0000        -6.0000        1_618.0000
# 1                   366.0000        -6.0000        1_619.0000
# 2                   369.0000        -6.0000        1_619.0000
# 3                   367.0000        -6.0000        1_616.0000
# 4                   368.0000        -6.0000        1_615.0000
# ...                      ...            ...               ...
# 714420                   NaN            NaN               NaN
# 714421                   NaN            NaN               NaN
# 714422                   NaN            NaN               NaN
# 714423                   NaN            NaN               NaN
# 714424                   NaN            NaN               NaN
#
#         fuel_mix.natural_gas  fuel_mix.large_hydro  fuel_mix.batteries  \
# 0                 8_722.0000            3_425.0000              1.0000
# 1                 8_739.0000            3_464.0000              6.0000
# 2                 8_696.0000            3_470.0000            -14.0000
# 3                 8_605.0000            3_454.0000            -38.0000
# 4                 8_550.0000            3_421.0000            -39.0000
# ...                      ...                   ...                 ...
# 714420                   NaN                   NaN                 NaN
# 714421                   NaN                   NaN                 NaN
# 714422                   NaN                   NaN                 NaN
# 714423                   NaN                   NaN                 NaN
# 714424                   NaN                   NaN                 NaN
#
#         fuel_mix.imports  fuel_mix.other  storage.supply  \
# 0             7_029.0000          0.0000             NaN
# 1             6_873.0000          0.0000             NaN
# 2             6_744.0000          0.0000             NaN
# 3             6_757.0000          0.0000             NaN
# 4             6_720.0000          0.0000             NaN
# ...                  ...             ...             ...
# 714420               NaN             NaN             NaN
# 714421               NaN             NaN             NaN
# 714422               NaN             NaN             NaN
# 714423               NaN             NaN             NaN
# 714424               NaN             NaN             NaN
#
#         storage.stand_alone_batteries  storage.hybrid_batteries  \
# 0                                 NaN                       NaN
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 3                                 NaN                       NaN
# 4                                 NaN                       NaN
# ...                               ...                       ...
# 714420                            NaN                       NaN
# 714421                            NaN                       NaN
# 714422                            NaN                       NaN
# 714423                            NaN                       NaN
# 714424                            NaN                       NaN
#
#         battery_discharge_to_load_ratio  battery_charge_to_load_ratio
# 0                                0.0000                       -0.0000
# 1                                0.0003                       -0.0003
# 2                               -0.0006                        0.0006
# 3                               -0.0017                        0.0017
# 4                               -0.0018                        0.0018
# ...                                 ...                           ...
# 714420                              NaN                           NaN
# 714421                              NaN                           NaN
# 714422                              NaN                           NaN
# 714423                              NaN                           NaN
# 714424                              NaN                           NaN
#
# [714425 rows x 30 columns]

# %%
df
# Out:
#             interval_start_local        interval_start_utc  \
# 0      2018-04-10 00:05:00-07:00 2018-04-10 07:05:00+00:00
# 1      2018-04-10 00:10:00-07:00 2018-04-10 07:10:00+00:00
# 2      2018-04-10 00:15:00-07:00 2018-04-10 07:15:00+00:00
# 3      2018-04-10 00:20:00-07:00 2018-04-10 07:20:00+00:00
# 4      2018-04-10 00:25:00-07:00 2018-04-10 07:25:00+00:00
# ...                          ...                       ...
# 714420 2025-01-23 14:05:00-08:00 2025-01-23 22:05:00+00:00
# 714421 2025-01-23 14:10:00-08:00 2025-01-23 22:10:00+00:00
# 714422 2025-01-23 14:15:00-08:00 2025-01-23 22:15:00+00:00
# 714423 2025-01-23 14:20:00-08:00 2025-01-23 22:20:00+00:00
# 714424 2025-01-23 14:25:00-08:00 2025-01-23 22:25:00+00:00
#
#               interval_end_local          interval_end_utc    net_load  \
# 0      2018-04-10 00:10:00-07:00 2018-04-10 07:10:00+00:00 21_953.0000
# 1      2018-04-10 00:15:00-07:00 2018-04-10 07:15:00+00:00 21_865.0000
# 2      2018-04-10 00:20:00-07:00 2018-04-10 07:20:00+00:00 21_687.0000
# 3      2018-04-10 00:25:00-07:00 2018-04-10 07:25:00+00:00 21_579.0000
# 4      2018-04-10 00:30:00-07:00 2018-04-10 07:30:00+00:00 21_432.0000
# ...                          ...                       ...         ...
# 714420 2025-01-23 14:10:00-08:00 2025-01-23 22:10:00+00:00         NaN
# 714421 2025-01-23 14:15:00-08:00 2025-01-23 22:15:00+00:00         NaN
# 714422 2025-01-23 14:20:00-08:00 2025-01-23 22:20:00+00:00         NaN
# 714423 2025-01-23 14:25:00-08:00 2025-01-23 22:25:00+00:00         NaN
# 714424 2025-01-23 14:30:00-08:00 2025-01-23 22:30:00+00:00         NaN
#
#         renewables  renewables_to_load_ratio primary_power_source   load.load  \
# 0       5_430.0000                    0.2427          natural_gas 22_371.0000
# 1       5_512.0000                    0.2468          natural_gas 22_330.0000
# 2       5_449.0000                    0.2468          natural_gas 22_082.0000
# 3       5_434.0000                    0.2472          natural_gas 21_978.0000
# 4       5_413.0000                    0.2478          natural_gas 21_844.0000
# ...            ...                       ...                  ...         ...
# 714420         NaN                       NaN                 None         NaN
# 714421         NaN                       NaN                 None         NaN
# 714422         NaN                       NaN                 None         NaN
# 714423         NaN                       NaN                 None         NaN
# 714424         NaN                       NaN                 None         NaN
#
#        load_forecast.publish_time_local load_forecast.publish_time_utc  \
# 0             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 1             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 2             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 3             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 4             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# ...                                 ...                            ...
# 714420        2025-01-22 09:10:00-08:00      2025-01-22 17:10:00+00:00
# 714421        2025-01-22 09:10:00-08:00      2025-01-22 17:10:00+00:00
# 714422        2025-01-22 09:10:00-08:00      2025-01-22 17:10:00+00:00
# 714423        2025-01-22 09:10:00-08:00      2025-01-22 17:10:00+00:00
# 714424        2025-01-22 09:10:00-08:00      2025-01-22 17:10:00+00:00
#
#         load_forecast.load_forecast  fuel_mix.solar  fuel_mix.wind  \
# 0                       22_362.7808          0.0000       418.0000
# 1                       22_260.1467          0.0000       465.0000
# 2                       22_157.5125          0.0000       395.0000
# 3                       22_054.8783          0.0000       399.0000
# 4                       21_952.2442          0.0000       412.0000
# ...                             ...             ...            ...
# 714420                  19_022.1800             NaN            NaN
# 714421                  19_022.1800             NaN            NaN
# 714422                  19_022.1800             NaN            NaN
# 714423                  19_022.1800             NaN            NaN
# 714424                  19_022.1800             NaN            NaN
#
#         fuel_mix.geothermal  fuel_mix.biomass  fuel_mix.biogas  \
# 0                  689.0000          296.0000         232.0000
# 1                  688.0000          297.0000         232.0000
# 2                  687.0000          296.0000         232.0000
# 3                  686.0000          295.0000         233.0000
# 4                  687.0000          293.0000         232.0000
# ...                     ...               ...              ...
# 714420                  NaN               NaN              NaN
# 714421                  NaN               NaN              NaN
# 714422                  NaN               NaN              NaN
# 714423                  NaN               NaN              NaN
# 714424                  NaN               NaN              NaN
#
#         fuel_mix.small_hydro  fuel_mix.coal  fuel_mix.nuclear  \
# 0                   370.0000        -6.0000        1_618.0000
# 1                   366.0000        -6.0000        1_619.0000
# 2                   369.0000        -6.0000        1_619.0000
# 3                   367.0000        -6.0000        1_616.0000
# 4                   368.0000        -6.0000        1_615.0000
# ...                      ...            ...               ...
# 714420                   NaN            NaN               NaN
# 714421                   NaN            NaN               NaN
# 714422                   NaN            NaN               NaN
# 714423                   NaN            NaN               NaN
# 714424                   NaN            NaN               NaN
#
#         fuel_mix.natural_gas  fuel_mix.large_hydro  fuel_mix.batteries  \
# 0                 8_722.0000            3_425.0000              1.0000
# 1                 8_739.0000            3_464.0000              6.0000
# 2                 8_696.0000            3_470.0000            -14.0000
# 3                 8_605.0000            3_454.0000            -38.0000
# 4                 8_550.0000            3_421.0000            -39.0000
# ...                      ...                   ...                 ...
# 714420                   NaN                   NaN                 NaN
# 714421                   NaN                   NaN                 NaN
# 714422                   NaN                   NaN                 NaN
# 714423                   NaN                   NaN                 NaN
# 714424                   NaN                   NaN                 NaN
#
#         fuel_mix.imports  fuel_mix.other  storage.supply  \
# 0             7_029.0000          0.0000             NaN
# 1             6_873.0000          0.0000             NaN
# 2             6_744.0000          0.0000             NaN
# 3             6_757.0000          0.0000             NaN
# 4             6_720.0000          0.0000             NaN
# ...                  ...             ...             ...
# 714420               NaN             NaN             NaN
# 714421               NaN             NaN             NaN
# 714422               NaN             NaN             NaN
# 714423               NaN             NaN             NaN
# 714424               NaN             NaN             NaN
#
#         storage.stand_alone_batteries  storage.hybrid_batteries  \
# 0                                 NaN                       NaN
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 3                                 NaN                       NaN
# 4                                 NaN                       NaN
# ...                               ...                       ...
# 714420                            NaN                       NaN
# 714421                            NaN                       NaN
# 714422                            NaN                       NaN
# 714423                            NaN                       NaN
# 714424                            NaN                       NaN
#
#         battery_discharge_to_load_ratio  battery_charge_to_load_ratio
# 0                                0.0000                       -0.0000
# 1                                0.0003                       -0.0003
# 2                               -0.0006                        0.0006
# 3                               -0.0017                        0.0017
# 4                               -0.0018                        0.0018
# ...                                 ...                           ...
# 714420                              NaN                           NaN
# 714421                              NaN                           NaN
# 714422                              NaN                           NaN
# 714423                              NaN                           NaN
# 714424                              NaN                           NaN
#
# [714425 rows x 30 columns]

# %% [markdown]
# ## Preprocessing data
#
# Extract the data for the month of April and create additional columns for year and time. Then, calculate the average net load for each year and time combination.

# %%
apr_data = df[df["interval_start_local"].dt.month == 4].copy()

apr_data["year"] = apr_data["interval_start_local"].dt.year
apr_data["hh:mm"] = apr_data["interval_start_local"].dt.strftime("%H:%M")

net_load_apr_avg = (
    apr_data.groupby(["year", "hh:mm"])[["net_load"]].mean().reset_index()
)

# append 24:00 so tick shows up on plot
net_load_apr_avg = pd.concat(
    [net_load_apr_avg, pd.DataFrame({"year": 2023, "hh:mm": ["24:00"]})]
)

net_load_apr_avg
# Out:
#       year  hh:mm      net_load
# 0     2018  00:00  18838.100000
# 1     2018  00:05  18886.380952
# 2     2018  00:10  18831.476190
# 3     2018  00:15  18728.571429
# 4     2018  00:20  18629.190476
# ...    ...    ...           ...
# 2300  2025  23:40  18460.233333
# 2301  2025  23:45  18362.366667
# 2302  2025  23:50  18245.966667
# 2303  2025  23:55  18080.703704
# 0     2023  24:00           NaN
#
# [2305 rows x 3 columns]

# %% [markdown]
# ## Preprocessing data for minimum net load day in 2023
#
# Extract the data for 2023 and find the day with the minimum net load.

# %%
apr_2023 = apr_data[apr_data["year"] == 2023]

# get time min load occurred in 2033
min_net_load_time = apr_2023.loc[apr_2023["net_load"].idxmin(), "interval_start_local"]

# select data for only that day
min_net_load_day_2023 = apr_2023[
    apr_2023["interval_start_local"].dt.date == min_net_load_time.date()
]
min_net_load_day_2023[["interval_start_local", "hh:mm", "net_load"]]
# Out:
#             interval_start_local  hh:mm  net_load
# 529631 2023-04-23 00:00:00-07:00  00:00   17487.0
# 529632 2023-04-23 00:05:00-07:00  00:05   17590.0
# 529633 2023-04-23 00:10:00-07:00  00:10   17558.0
# 529634 2023-04-23 00:15:00-07:00  00:15   17402.0
# 529635 2023-04-23 00:20:00-07:00  00:20   17285.0
# ...                          ...    ...       ...
# 529914 2023-04-23 23:35:00-07:00  23:35   16612.0
# 529915 2023-04-23 23:40:00-07:00  23:40   16423.0
# 529916 2023-04-23 23:45:00-07:00  23:45   16266.0
# 529917 2023-04-23 23:50:00-07:00  23:50   16137.0
# 529918 2023-04-23 23:55:00-07:00  23:55   16055.0
#
# [288 rows x 3 columns]

# %% [markdown]
# ## Plotting data with Plotly
#
# Here we create an interactive plot using Plotly. We plot net load over time for each year, with different colors for different years, and also add a special line for the day in 2023 with the minimum net load.

# %%
import plotly.express as px

fig = go.Figure()

# Get unique years and define color gradient
unique_years = net_load_apr_avg["year"].unique()
blues = px.colors.sequential.Blues[: len(unique_years)]

# Add line traces for net_load per year
for year, color in zip(unique_years, blues):
    # Filter net load data for the current year
    year_data = net_load_apr_avg[net_load_apr_avg["year"] == year]

    fig.add_trace(
        go.Scatter(
            x=year_data["hh:mm"],
            y=year_data["net_load"] / 1000,
            mode="lines",
            name=str(year),
            line=dict(color=color, width=3),
            opacity=min(0.6 + (year - 2017) * 0.075, 1),
        )
    )

# Add trace for minimum net_load_day in 2023
fig.add_trace(
    go.Scatter(
        x=min_net_load_day_2023["hh:mm"],
        y=min_net_load_day_2023["net_load"] / 1000,
        mode="lines",
        name="2023 Minimum Day",
        line=dict(color="#4a69bb", width=4, dash="dash"),
        opacity=1,
    )
)

# Define axis tick values
x_tick_values = ["00:00", "06:00", "12:00", "18:00", "24:00"]
y_tick_values = [0, 10, 20, 25]

# Update layout with title, subtitle, and custom axis tick labels
fig.update_layout(
    title="Average Net Load in April in California<br><span style='font-size:0.8em;color:gray'>Net Load regularly below 0 for first time in April 2023 </span>",  # noqa
    xaxis=dict(
        tickmode="array",
        tickvals=x_tick_values,
        ticktext=["12am", "6am", "12pm", "6pm", "12am"],
    ),
    yaxis=dict(tickmode="array", tickvals=y_tick_values, ticktext=[0, 10, 20, "25 GW"]),
    template="plotly_dark",
)

# Define annotations
annotations = [
    {
        "x": "06:30",
        "text": "Morning Peak",
        "y_shift": 35,
        "time": "06:00",
        #  font size
        "font_size": 20,
    },
    {"x": "20:20", "text": "Evening Peak", "y_shift": 160, "time": "18:00"},
]

# Add annotations for morning and evening peaks
for annotation in annotations:
    fig.add_annotation(
        x=annotation["x"],
        y=net_load_apr_avg[net_load_apr_avg["hh:mm"] == annotation["time"]][
            "net_load"
        ].max()
        / 1000,
        text=annotation["text"],
        showarrow=False,
        yshift=annotation["y_shift"],
        font=dict(color="white", size=18),
    )

# Diplay the figure as an interactive plot
fig.update_layout(width=1200, height=800)
fig.show()

# %%
# Display the figure as svg
fig.show("svg")

# %% [markdown]
# ## Conclusion
#
# We have now plotted the average net load in April in California over several years, highlighting the year 2023 which was the first time the net load regularly went below zero. This information is invaluable for understanding changes in energy consumption and generation patterns over time.

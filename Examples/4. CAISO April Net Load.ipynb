# %% [markdown]
# ## CAISO April Net Load Trends
#
# We will be using the gridstatusio API client for data fetching, and Plotly for data visualization. You can register for a Grid Status api key here: https://www.gridstatus.io/api
#
# ### Installation
#
# To run this notebook, install the gridstatusio package with notebook dependencies:
#
# ```bash
# uv pip install gridstatusio[notebooks]
# ```

# %%
import pandas as pd
import plotly.graph_objects as go

import gridstatusio

gridstatusio.__version__
# Out:
# '0.15.1'

# %% [markdown]
# ## Initialize the gridstatusio client
#
# We instantiate the GridStatusClient, which we will use to fetch our data.

# %%
# Make sure to set up an API Key as an environment variable
# or pass it in as a string
client = gridstatusio.GridStatusClient()
# Out:
# GridStatusClient(host=https://api.gridstatus.io/v1)

# %% [markdown]
# ## Get data
#
# Fetch data using the GridStatusClient. We will get the `caiso_standardized_5_min` dataset from the beginning of the data to the most recent data.
#
# We are setting a `limit` value for our queries to prevent them from returning too many rows. Our `limit` is relatively high in this notebook and if you are on a Grid Status free plan, you will want to set a much lower `limit` to avoid quickly using your monthly row limit.
#
# The monthly row limit for the free plan is 1 million rows. The first tier Pro plan is 50 million rows.

# %%
QUERY_LIMIT = 750_000
# Out:
# 750000

# %%
import warnings

warnings.filterwarnings("ignore")

df = client.get_dataset(
    dataset="caiso_standardized_5_min",
    start=None,  # start from beginning of data
    end=None,  # end at most recent data
    timezone="market",  # return time stamps in market time. In this case, Pacific Time
)
# Out:
# 2026-01-10 19:47:04 - INFO - Fetching Page 1...
# 2026-01-10 19:47:04 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:47:04 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:47:11 - INFO - Done in 7.08 seconds.
# 2026-01-10 19:47:11 - INFO - Fetching Page 2...
# 2026-01-10 19:47:11 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:47:11 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 2, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAxOS0wMy0yMyAxMjoyMDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6MTAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:47:17 - INFO - Done in 6.51 seconds. Total time: 13.59s. Avg per page: 6.79s
# 2026-01-10 19:47:17 - INFO - Fetching Page 3...
# 2026-01-10 19:47:17 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:47:17 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 3, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAyMC0wMy0wNCAxNzo0MDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6MjAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:47:24 - INFO - Done in 6.6 seconds. Total time: 20.19s. Avg per page: 6.73s
# 2026-01-10 19:47:24 - INFO - Fetching Page 4...
# 2026-01-10 19:47:24 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:47:24 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 4, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAyMS0wMi0xNCAyMzowMDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6MzAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:47:24 - INFO - Too Many Requests. Limit: 6 per 1 second.. Retrying in 2 seconds. Retry 1 of 5.
# 2026-01-10 19:47:33 - INFO - Done in 9.03 seconds. Total time: 29.22s. Avg per page: 7.3s
# 2026-01-10 19:47:33 - INFO - Fetching Page 5...
# 2026-01-10 19:47:33 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:47:33 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 5, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAyMi0wMS0yOCAwNDoyMDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6NDAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:47:40 - INFO - Done in 6.99 seconds. Total time: 36.21s. Avg per page: 7.24s
# 2026-01-10 19:47:40 - INFO - Fetching Page 6...
# 2026-01-10 19:47:40 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:47:40 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 6, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAyMy0wMS0xMCAwOTo0MDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6NTAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:47:47 - INFO - Done in 7.19 seconds. Total time: 43.4s. Avg per page: 7.23s
# 2026-01-10 19:47:47 - INFO - Fetching Page 7...
# 2026-01-10 19:47:47 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:47:47 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 7, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAyMy0xMi0yMyAxNTowMDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6NjAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:47:54 - INFO - Done in 6.91 seconds. Total time: 50.31s. Avg per page: 7.19s
# 2026-01-10 19:47:54 - INFO - Fetching Page 8...
# 2026-01-10 19:47:54 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:47:54 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 8, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAyNC0xMi0wNCAyMDoyMDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6NzAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:48:01 - INFO - Done in 6.78 seconds. Total time: 57.09s. Avg per page: 7.14s
# 2026-01-10 19:48:01 - INFO - Fetching Page 9...
# 2026-01-10 19:48:01 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:48:01 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 9, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAyNS0xMS0xNyAwMTo0MDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6ODAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:48:02 - INFO - Done in 1.41 seconds. Total time: 58.5s. Avg per page: 6.5s
# 2026-01-10 19:48:03 - INFO - Total number of rows: 816209
#             interval_start_local        interval_start_utc  \
# 0      2018-04-10 00:05:00-07:00 2018-04-10 07:05:00+00:00
# 1      2018-04-10 00:10:00-07:00 2018-04-10 07:10:00+00:00
# 2      2018-04-10 00:15:00-07:00 2018-04-10 07:15:00+00:00
# 3      2018-04-10 00:20:00-07:00 2018-04-10 07:20:00+00:00
# 4      2018-04-10 00:25:00-07:00 2018-04-10 07:25:00+00:00
# ...                          ...                       ...
# 816204 2026-01-12 00:05:00-08:00 2026-01-12 08:05:00+00:00
# 816205 2026-01-12 00:10:00-08:00 2026-01-12 08:10:00+00:00
# 816206 2026-01-12 00:15:00-08:00 2026-01-12 08:15:00+00:00
# 816207 2026-01-12 00:20:00-08:00 2026-01-12 08:20:00+00:00
# 816208 2026-01-12 00:25:00-08:00 2026-01-12 08:25:00+00:00
#
#               interval_end_local          interval_end_utc    net_load  \
# 0      2018-04-10 00:10:00-07:00 2018-04-10 07:10:00+00:00 21_953.0000
# 1      2018-04-10 00:15:00-07:00 2018-04-10 07:15:00+00:00 21_865.0000
# 2      2018-04-10 00:20:00-07:00 2018-04-10 07:20:00+00:00 21_687.0000
# 3      2018-04-10 00:25:00-07:00 2018-04-10 07:25:00+00:00 21_579.0000
# 4      2018-04-10 00:30:00-07:00 2018-04-10 07:30:00+00:00 21_432.0000
# ...                          ...                       ...         ...
# 816204 2026-01-12 00:10:00-08:00 2026-01-12 08:10:00+00:00         NaN
# 816205 2026-01-12 00:15:00-08:00 2026-01-12 08:15:00+00:00         NaN
# 816206 2026-01-12 00:20:00-08:00 2026-01-12 08:20:00+00:00         NaN
# 816207 2026-01-12 00:25:00-08:00 2026-01-12 08:25:00+00:00         NaN
# 816208 2026-01-12 00:30:00-08:00 2026-01-12 08:30:00+00:00         NaN
#
#         renewables  renewables_to_load_ratio primary_power_source   load.load  \
# 0       5_430.0000                    0.2427          natural_gas 22_371.0000
# 1       5_512.0000                    0.2468          natural_gas 22_330.0000
# 2       5_449.0000                    0.2468          natural_gas 22_082.0000
# 3       5_434.0000                    0.2472          natural_gas 21_978.0000
# 4       5_413.0000                    0.2478          natural_gas 21_844.0000
# ...            ...                       ...                  ...         ...
# 816204         NaN                       NaN                 None         NaN
# 816205         NaN                       NaN                 None         NaN
# 816206         NaN                       NaN                 None         NaN
# 816207         NaN                       NaN                 None         NaN
# 816208         NaN                       NaN                 None         NaN
#
#        load_forecast.publish_time_local load_forecast.publish_time_utc  \
# 0             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 1             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 2             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 3             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 4             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# ...                                 ...                            ...
# 816204        2026-01-10 09:10:00-08:00      2026-01-10 17:10:00+00:00
# 816205        2026-01-10 09:10:00-08:00      2026-01-10 17:10:00+00:00
# 816206        2026-01-10 09:10:00-08:00      2026-01-10 17:10:00+00:00
# 816207        2026-01-10 09:10:00-08:00      2026-01-10 17:10:00+00:00
# 816208        2026-01-10 09:10:00-08:00      2026-01-10 17:10:00+00:00
#
#         load_forecast.load_forecast  fuel_mix.solar  fuel_mix.wind  \
# 0                       22_362.7808          0.0000       418.0000
# 1                       22_260.1467          0.0000       465.0000
# 2                       22_157.5125          0.0000       395.0000
# 3                       22_054.8783          0.0000       399.0000
# 4                       21_952.2442          0.0000       412.0000
# ...                             ...             ...            ...
# 816204                  21_541.9400             NaN            NaN
# 816205                  21_541.9400             NaN            NaN
# 816206                  21_541.9400             NaN            NaN
# 816207                  21_541.9400             NaN            NaN
# 816208                  21_541.9400             NaN            NaN
#
#         fuel_mix.geothermal  fuel_mix.biomass  fuel_mix.biogas  \
# 0                  689.0000          296.0000         232.0000
# 1                  688.0000          297.0000         232.0000
# 2                  687.0000          296.0000         232.0000
# 3                  686.0000          295.0000         233.0000
# 4                  687.0000          293.0000         232.0000
# ...                     ...               ...              ...
# 816204                  NaN               NaN              NaN
# 816205                  NaN               NaN              NaN
# 816206                  NaN               NaN              NaN
# 816207                  NaN               NaN              NaN
# 816208                  NaN               NaN              NaN
#
#         fuel_mix.small_hydro  fuel_mix.coal  fuel_mix.nuclear  \
# 0                   370.0000        -6.0000        1_618.0000
# 1                   366.0000        -6.0000        1_619.0000
# 2                   369.0000        -6.0000        1_619.0000
# 3                   367.0000        -6.0000        1_616.0000
# 4                   368.0000        -6.0000        1_615.0000
# ...                      ...            ...               ...
# 816204                   NaN            NaN               NaN
# 816205                   NaN            NaN               NaN
# 816206                   NaN            NaN               NaN
# 816207                   NaN            NaN               NaN
# 816208                   NaN            NaN               NaN
#
#         fuel_mix.natural_gas  fuel_mix.large_hydro  fuel_mix.batteries  \
# 0                 8_722.0000            3_425.0000              1.0000
# 1                 8_739.0000            3_464.0000              6.0000
# 2                 8_696.0000            3_470.0000            -14.0000
# 3                 8_605.0000            3_454.0000            -38.0000
# 4                 8_550.0000            3_421.0000            -39.0000
# ...                      ...                   ...                 ...
# 816204                   NaN                   NaN                 NaN
# 816205                   NaN                   NaN                 NaN
# 816206                   NaN                   NaN                 NaN
# 816207                   NaN                   NaN                 NaN
# 816208                   NaN                   NaN                 NaN
#
#         fuel_mix.imports  fuel_mix.other  storage.supply  \
# 0             7_029.0000          0.0000             NaN
# 1             6_873.0000          0.0000             NaN
# 2             6_744.0000          0.0000             NaN
# 3             6_757.0000          0.0000             NaN
# 4             6_720.0000          0.0000             NaN
# ...                  ...             ...             ...
# 816204               NaN             NaN             NaN
# 816205               NaN             NaN             NaN
# 816206               NaN             NaN             NaN
# 816207               NaN             NaN             NaN
# 816208               NaN             NaN             NaN
#
#         storage.stand_alone_batteries  storage.hybrid_batteries  \
# 0                                 NaN                       NaN
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 3                                 NaN                       NaN
# 4                                 NaN                       NaN
# ...                               ...                       ...
# 816204                            NaN                       NaN
# 816205                            NaN                       NaN
# 816206                            NaN                       NaN
# 816207                            NaN                       NaN
# 816208                            NaN                       NaN
#
#         battery_discharge_to_load_ratio  battery_charge_to_load_ratio
# 0                                0.0000                       -0.0000
# 1                                0.0003                       -0.0003
# 2                               -0.0006                        0.0006
# 3                               -0.0017                        0.0017
# 4                               -0.0018                        0.0018
# ...                                 ...                           ...
# 816204                              NaN                           NaN
# 816205                              NaN                           NaN
# 816206                              NaN                           NaN
# 816207                              NaN                           NaN
# 816208                              NaN                           NaN
#
# [816209 rows x 30 columns]

# %%
import warnings

warnings.filterwarnings("ignore")

df = client.get_dataset(
    dataset="caiso_standardized_5_min",
    start=None,  # start from beginning of data
    end=None,  # end at most recent data
    timezone="market",  # return time stamps in market time. In this case, Pacific Time
    limit=QUERY_LIMIT,
)

df.head()

df.tail()

df.info()
# Out:
# 2026-01-10 19:48:08 - INFO - Fetching Page 1...
# 2026-01-10 19:48:08 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:48:08 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': 750000, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:48:16 - INFO - Done in 8.1 seconds.
# 2026-01-10 19:48:16 - INFO - Total rows: 100,000/750,000 (13.33% of limit)
# 2026-01-10 19:48:16 - INFO - Fetching Page 2...
# 2026-01-10 19:48:16 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:48:16 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': 750000, 'page': 2, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAxOS0wMy0yMyAxMjoyMDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6MTAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:48:23 - INFO - Done in 7.02 seconds. Total time: 15.11s. Avg per page: 7.56s
# 2026-01-10 19:48:23 - INFO - Total rows: 200,000/750,000 (26.67% of limit)
# 2026-01-10 19:48:23 - INFO - Fetching Page 3...
# 2026-01-10 19:48:23 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:48:23 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': 750000, 'page': 3, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAyMC0wMy0wNCAxNzo0MDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6MjAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:48:30 - INFO - Done in 6.79 seconds. Total time: 21.9s. Avg per page: 7.3s
# 2026-01-10 19:48:30 - INFO - Total rows: 300,000/750,000 (40.0% of limit)
# 2026-01-10 19:48:30 - INFO - Fetching Page 4...
# 2026-01-10 19:48:30 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:48:30 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': 750000, 'page': 4, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAyMS0wMi0xNCAyMzowMDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6MzAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:48:37 - INFO - Done in 6.39 seconds. Total time: 28.29s. Avg per page: 7.07s
# 2026-01-10 19:48:37 - INFO - Total rows: 400,000/750,000 (53.33% of limit)
# 2026-01-10 19:48:37 - INFO - Fetching Page 5...
# 2026-01-10 19:48:37 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:48:37 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': 750000, 'page': 5, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAyMi0wMS0yOCAwNDoyMDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6NDAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:48:43 - INFO - Done in 6.95 seconds. Total time: 35.24s. Avg per page: 7.05s
# 2026-01-10 19:48:43 - INFO - Total rows: 500,000/750,000 (66.67% of limit)
# 2026-01-10 19:48:43 - INFO - Fetching Page 6...
# 2026-01-10 19:48:43 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:48:43 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': 750000, 'page': 6, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAyMy0wMS0xMCAwOTo0MDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6NTAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:48:51 - INFO - Done in 7.21 seconds. Total time: 42.45s. Avg per page: 7.08s
# 2026-01-10 19:48:51 - INFO - Total rows: 600,000/750,000 (80.0% of limit)
# 2026-01-10 19:48:51 - INFO - Fetching Page 7...
# 2026-01-10 19:48:51 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:48:51 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': 750000, 'page': 7, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAyMy0xMi0yMyAxNTowMDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6NjAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:48:58 - INFO - Done in 7.35 seconds. Total time: 49.8s. Avg per page: 7.11s
# 2026-01-10 19:48:58 - INFO - Total rows: 700,000/750,000 (93.33% of limit)
# 2026-01-10 19:48:58 - INFO - Fetching Page 8...
# 2026-01-10 19:48:58 - INFO - GET https://api.gridstatus.io/v1/datasets/caiso_standardized_5_min/query
# 2026-01-10 19:48:58 - INFO - Params: {'start_time': None, 'end_time': None, 'publish_time_start': None, 'publish_time_end': None, 'limit': 750000, 'page': 8, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjpbImludGVydmFsX3N0YXJ0X3V0YyJdLCJ2YWx1ZXMiOlsiMjAyNC0xMi0wNCAyMDoyMDowMCswMDowMCJdLCJ0b3RhbF9yb3dzX3JldHVybmVkX3NvX2ZhciI6NzAwMDAwfQ==', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2026-01-10 19:49:01 - INFO - Done in 3.41 seconds. Total time: 53.21s. Avg per page: 6.65s
# 2026-01-10 19:49:01 - INFO - Total rows: 750,000/750,000 (100.0% of limit)
# 2026-01-10 19:49:03 - INFO - Total number of rows: 750000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   interval_start_local              750000 non-null  datetime64[ns, US/Pacific]
#  1   interval_start_utc                750000 non-null  datetime64[ns, UTC]
#  2   interval_end_local                750000 non-null  datetime64[ns, US/Pacific]
#  3   interval_end_utc                  750000 non-null  datetime64[ns, UTC]
#  4   net_load                          749727 non-null  float64
#  5   renewables                        749753 non-null  float64
#  6   renewables_to_load_ratio          749727 non-null  float64
#  7   primary_power_source              749754 non-null  object
#  8   load.load                         749730 non-null  float64
#  9   load_forecast.publish_time_local  750000 non-null  datetime64[ns, US/Pacific]
#  10  load_forecast.publish_time_utc    750000 non-null  datetime64[ns, UTC]
#  11  load_forecast.load_forecast       750000 non-null  float64
#  12  fuel_mix.solar                    749466 non-null  float64
#  13  fuel_mix.wind                     749753 non-null  float64
#  14  fuel_mix.geothermal               749464 non-null  float64
#  15  fuel_mix.biomass                  749754 non-null  float64
#  16  fuel_mix.biogas                   749754 non-null  float64
#  17  fuel_mix.small_hydro              749754 non-null  float64
#  18  fuel_mix.coal                     749753 non-null  float64
#  19  fuel_mix.nuclear                  749754 non-null  float64
#  20  fuel_mix.natural_gas              749466 non-null  float64
#  21  fuel_mix.large_hydro              749754 non-null  float64
#  22  fuel_mix.batteries                749754 non-null  float64
#  23  fuel_mix.imports                  749466 non-null  float64
#  24  fuel_mix.other                    749465 non-null  float64
#  25  storage.supply                    228997 non-null  float64
#  26  storage.stand_alone_batteries     228997 non-null  float64
#  27  storage.hybrid_batteries          228997 non-null  float64
#  28  battery_discharge_to_load_ratio   749728 non-null  float64
#  29  battery_charge_to_load_ratio      749728 non-null  float64
# dtypes: datetime64[ns, US/Pacific](3), datetime64[ns, UTC](3), float64(23), object(1)
# memory usage: 171.7+ MB

# %%
df
# Out:
#             interval_start_local        interval_start_utc  \
# 0      2018-04-10 00:05:00-07:00 2018-04-10 07:05:00+00:00
# 1      2018-04-10 00:10:00-07:00 2018-04-10 07:10:00+00:00
# 2      2018-04-10 00:15:00-07:00 2018-04-10 07:15:00+00:00
# 3      2018-04-10 00:20:00-07:00 2018-04-10 07:20:00+00:00
# 4      2018-04-10 00:25:00-07:00 2018-04-10 07:25:00+00:00
# ...                          ...                       ...
# 749995 2025-05-27 03:40:00-07:00 2025-05-27 10:40:00+00:00
# 749996 2025-05-27 03:45:00-07:00 2025-05-27 10:45:00+00:00
# 749997 2025-05-27 03:50:00-07:00 2025-05-27 10:50:00+00:00
# 749998 2025-05-27 03:55:00-07:00 2025-05-27 10:55:00+00:00
# 749999 2025-05-27 04:00:00-07:00 2025-05-27 11:00:00+00:00
#
#               interval_end_local          interval_end_utc    net_load  \
# 0      2018-04-10 00:10:00-07:00 2018-04-10 07:10:00+00:00 21_953.0000
# 1      2018-04-10 00:15:00-07:00 2018-04-10 07:15:00+00:00 21_865.0000
# 2      2018-04-10 00:20:00-07:00 2018-04-10 07:20:00+00:00 21_687.0000
# 3      2018-04-10 00:25:00-07:00 2018-04-10 07:25:00+00:00 21_579.0000
# 4      2018-04-10 00:30:00-07:00 2018-04-10 07:30:00+00:00 21_432.0000
# ...                          ...                       ...         ...
# 749995 2025-05-27 03:45:00-07:00 2025-05-27 10:45:00+00:00 17_163.0000
# 749996 2025-05-27 03:50:00-07:00 2025-05-27 10:50:00+00:00 17_130.0000
# 749997 2025-05-27 03:55:00-07:00 2025-05-27 10:55:00+00:00 17_136.0000
# 749998 2025-05-27 04:00:00-07:00 2025-05-27 11:00:00+00:00 17_213.0000
# 749999 2025-05-27 04:05:00-07:00 2025-05-27 11:05:00+00:00 17_185.0000
#
#         renewables  renewables_to_load_ratio primary_power_source   load.load  \
# 0       5_430.0000                    0.2427          natural_gas 22_371.0000
# 1       5_512.0000                    0.2468          natural_gas 22_330.0000
# 2       5_449.0000                    0.2468          natural_gas 22_082.0000
# 3       5_434.0000                    0.2472          natural_gas 21_978.0000
# 4       5_413.0000                    0.2478          natural_gas 21_844.0000
# ...            ...                       ...                  ...         ...
# 749995  8_782.0000                    0.4271              imports 20_564.0000
# 749996  8_916.0000                    0.4339              imports 20_548.0000
# 749997  8_822.0000                    0.4305              imports 20_491.0000
# 749998  8_387.0000                    0.4093              imports 20_492.0000
# 749999  8_258.0000                    0.4041              imports 20_437.0000
#
#        load_forecast.publish_time_local load_forecast.publish_time_utc  \
# 0             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 1             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 2             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 3             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# 4             2018-04-08 09:10:00-07:00      2018-04-08 16:10:00+00:00
# ...                                 ...                            ...
# 749995        2025-05-26 09:10:00-07:00      2025-05-26 16:10:00+00:00
# 749996        2025-05-26 09:10:00-07:00      2025-05-26 16:10:00+00:00
# 749997        2025-05-26 09:10:00-07:00      2025-05-26 16:10:00+00:00
# 749998        2025-05-26 09:10:00-07:00      2025-05-26 16:10:00+00:00
# 749999        2025-05-26 09:10:00-07:00      2025-05-26 16:10:00+00:00
#
#         load_forecast.load_forecast  fuel_mix.solar  fuel_mix.wind  \
# 0                       22_362.7808          0.0000       418.0000
# 1                       22_260.1467          0.0000       465.0000
# 2                       22_157.5125          0.0000       395.0000
# 3                       22_054.8783          0.0000       399.0000
# 4                       21_952.2442          0.0000       412.0000
# ...                             ...             ...            ...
# 749995                  20_365.9800        -20.0000     3_421.0000
# 749996                  20_387.8600        -20.0000     3_438.0000
# 749997                  20_409.7400        -20.0000     3_375.0000
# 749998                  20_431.6200        -20.0000     3_299.0000
# 749999                  20_453.5000        -20.0000     3_272.0000
#
#         fuel_mix.geothermal  fuel_mix.biomass  fuel_mix.biogas  \
# 0                  689.0000          296.0000         232.0000
# 1                  688.0000          297.0000         232.0000
# 2                  687.0000          296.0000         232.0000
# 3                  686.0000          295.0000         233.0000
# 4                  687.0000          293.0000         232.0000
# ...                     ...               ...              ...
# 749995             737.0000          244.0000         162.0000
# 749996             737.0000          245.0000         162.0000
# 749997             736.0000          247.0000         162.0000
# 749998             738.0000          246.0000         162.0000
# 749999             739.0000          245.0000         162.0000
#
#         fuel_mix.small_hydro  fuel_mix.coal  fuel_mix.nuclear  \
# 0                   370.0000        -6.0000        1_618.0000
# 1                   366.0000        -6.0000        1_619.0000
# 2                   369.0000        -6.0000        1_619.0000
# 3                   367.0000        -6.0000        1_616.0000
# 4                   368.0000        -6.0000        1_615.0000
# ...                      ...            ...               ...
# 749995              268.0000         0.0000        2_279.0000
# 749996              268.0000         0.0000        2_279.0000
# 749997              267.0000         0.0000        2_280.0000
# 749998              268.0000         0.0000        2_280.0000
# 749999              269.0000         0.0000        2_281.0000
#
#         fuel_mix.natural_gas  fuel_mix.large_hydro  fuel_mix.batteries  \
# 0                 8_722.0000            3_425.0000              1.0000
# 1                 8_739.0000            3_464.0000              6.0000
# 2                 8_696.0000            3_470.0000            -14.0000
# 3                 8_605.0000            3_454.0000            -38.0000
# 4                 8_550.0000            3_421.0000            -39.0000
# ...                      ...                   ...                 ...
# 749995            4_140.0000            3_970.0000            150.0000
# 749996            4_033.0000            4_086.0000            182.0000
# 749997            4_011.0000            4_055.0000            179.0000
# 749998            4_144.0000            3_694.0000            233.0000
# 749999            4_193.0000            3_591.0000            334.0000
#
#         fuel_mix.imports  fuel_mix.other  storage.supply  \
# 0             7_029.0000          0.0000             NaN
# 1             6_873.0000          0.0000             NaN
# 2             6_744.0000          0.0000             NaN
# 3             6_757.0000          0.0000             NaN
# 4             6_720.0000          0.0000             NaN
# ...                  ...             ...             ...
# 749995        4_811.0000          0.0000        150.0000
# 749996        4_758.0000          0.0000        182.0000
# 749997        4_813.0000          0.0000        179.0000
# 749998        5_054.0000          0.0000        233.0000
# 749999        5_037.0000          0.0000        333.0000
#
#         storage.stand_alone_batteries  storage.hybrid_batteries  \
# 0                                 NaN                       NaN
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 3                                 NaN                       NaN
# 4                                 NaN                       NaN
# ...                               ...                       ...
# 749995                        55.0000                  101.0000
# 749996                        80.0000                  102.0000
# 749997                        78.0000                  102.0000
# 749998                       140.0000                  102.0000
# 749999                       229.0000                  110.0000
#
#         battery_discharge_to_load_ratio  battery_charge_to_load_ratio
# 0                                0.0000                       -0.0000
# 1                                0.0003                       -0.0003
# 2                               -0.0006                        0.0006
# 3                               -0.0017                        0.0017
# 4                               -0.0018                        0.0018
# ...                                 ...                           ...
# 749995                           0.0073                       -0.0073
# 749996                           0.0089                       -0.0089
# 749997                           0.0087                       -0.0088
# 749998                           0.0114                       -0.0115
# 749999                           0.0163                       -0.0166
#
# [750000 rows x 30 columns]

# %% [markdown]
# ## Preprocessing data
#
# Extract the data for the month of April and create additional columns for year and time. Then, calculate the average net load for each year and time combination.

# %%
apr_data = df[df["interval_start_local"].dt.month == 4].copy()

apr_data["year"] = apr_data["interval_start_local"].dt.year
apr_data["hh:mm"] = apr_data["interval_start_local"].dt.strftime("%H:%M")

net_load_apr_avg = (
    apr_data.groupby(["year", "hh:mm"])[["net_load"]].mean().reset_index()
)

# append 24:00 so tick shows up on plot
net_load_apr_avg = pd.concat(
    [net_load_apr_avg, pd.DataFrame({"year": 2023, "hh:mm": ["24:00"]})]
)

net_load_apr_avg
# Out:
#       year  hh:mm    net_load
# 0     2018  00:00 18_838.1000
# 1     2018  00:05 18_886.3810
# 2     2018  00:10 18_831.4762
# 3     2018  00:15 18_728.5714
# 4     2018  00:20 18_629.1905
# ...    ...    ...         ...
# 2300  2025  23:40 18_460.2333
# 2301  2025  23:45 18_362.3667
# 2302  2025  23:50 18_245.9667
# 2303  2025  23:55 18_080.7037
# 0     2023  24:00         NaN
#
# [2305 rows x 3 columns]

# %% [markdown]
# ## Preprocessing data for minimum net load day in 2023
#
# Extract the data for 2023 and find the day with the minimum net load.

# %%
apr_2023 = apr_data[apr_data["year"] == 2023]

# get time min load occurred in 2033
min_net_load_time = apr_2023.loc[apr_2023["net_load"].idxmin(), "interval_start_local"]

# select data for only that day
min_net_load_day_2023 = apr_2023[
    apr_2023["interval_start_local"].dt.date == min_net_load_time.date()
]
min_net_load_day_2023[["interval_start_local", "hh:mm", "net_load"]]
# Out:
#             interval_start_local  hh:mm    net_load
# 529631 2023-04-23 00:00:00-07:00  00:00 17_487.0000
# 529632 2023-04-23 00:05:00-07:00  00:05 17_590.0000
# 529633 2023-04-23 00:10:00-07:00  00:10 17_558.0000
# 529634 2023-04-23 00:15:00-07:00  00:15 17_402.0000
# 529635 2023-04-23 00:20:00-07:00  00:20 17_285.0000
# ...                          ...    ...         ...
# 529914 2023-04-23 23:35:00-07:00  23:35 16_612.0000
# 529915 2023-04-23 23:40:00-07:00  23:40 16_423.0000
# 529916 2023-04-23 23:45:00-07:00  23:45 16_266.0000
# 529917 2023-04-23 23:50:00-07:00  23:50 16_137.0000
# 529918 2023-04-23 23:55:00-07:00  23:55 16_055.0000
#
# [288 rows x 3 columns]

# %% [markdown]
# ## Plotting data with Plotly
#
# Here we create an interactive plot using Plotly. We plot net load over time for each year, with different colors for different years, and also add a special line for the day in 2023 with the minimum net load.

# %%
import plotly.express as px

fig = go.Figure()

# Get unique years and define color gradient
unique_years = net_load_apr_avg["year"].unique()
blues = px.colors.sequential.Blues[: len(unique_years)]

# Add line traces for net_load per year
for year, color in zip(unique_years, blues):
    # Filter net load data for the current year
    year_data = net_load_apr_avg[net_load_apr_avg["year"] == year]

    fig.add_trace(
        go.Scatter(
            x=year_data["hh:mm"],
            y=year_data["net_load"] / 1000,
            mode="lines",
            name=str(year),
            line=dict(color=color, width=3),
            opacity=min(0.6 + (year - 2017) * 0.075, 1),
        )
    )

# Add trace for minimum net_load_day in 2023
fig.add_trace(
    go.Scatter(
        x=min_net_load_day_2023["hh:mm"],
        y=min_net_load_day_2023["net_load"] / 1000,
        mode="lines",
        name="2023 Minimum Day",
        line=dict(color="#4a69bb", width=4, dash="dash"),
        opacity=1,
    )
)

# Define axis tick values
x_tick_values = ["00:00", "06:00", "12:00", "18:00", "24:00"]
y_tick_values = [0, 10, 20, 25]

# Update layout with title, subtitle, and custom axis tick labels
fig.update_layout(
    title="Average Net Load in April in California<br><span style='font-size:0.8em;color:gray'>Net Load regularly below 0 for first time in April 2023 </span>",  # noqa
    xaxis=dict(
        tickmode="array",
        tickvals=x_tick_values,
        ticktext=["12am", "6am", "12pm", "6pm", "12am"],
    ),
    yaxis=dict(tickmode="array", tickvals=y_tick_values, ticktext=[0, 10, 20, "25 GW"]),
    template="plotly_dark",
)

# Define annotations
annotations = [
    {
        "x": "06:30",
        "text": "Morning Peak",
        "y_shift": 35,
        "time": "06:00",
        #  font size
        "font_size": 20,
    },
    {"x": "20:20", "text": "Evening Peak", "y_shift": 160, "time": "18:00"},
]

# Add annotations for morning and evening peaks
for annotation in annotations:
    fig.add_annotation(
        x=annotation["x"],
        y=net_load_apr_avg[net_load_apr_avg["hh:mm"] == annotation["time"]][
            "net_load"
        ].max()
        / 1000,
        text=annotation["text"],
        showarrow=False,
        yshift=annotation["y_shift"],
        font=dict(color="white", size=18),
    )

# Diplay the figure as an interactive plot
fig.update_layout(width=1200, height=800)
fig.show()

# %%
# Display the figure as svg
fig.show("svg")

# %% [markdown]
# ## Conclusion
#
# We have now plotted the average net load in April in California over several years, highlighting the year 2023 which was the first time the net load regularly went below zero. This information is invaluable for understanding changes in energy consumption and generation patterns over time.
